# %%
import tweepy as tp
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
consumer_key = ''
consumer_secret = ''
access_token = ''
access_token_secret = ''

# %%
auth = tp.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tp.API(auth)

tweets = api.search('CAA', count=400)
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])
display(data.head(10))
# Out:
#                                               Tweets
# 0  @aishvaryaV @TalwaiSarita @sandipanthedeb @Suh...
# 1  RT @pbhushan1: Do read this fine intervention ...
# 2  RT @ishkarnBHANDARI: Congress took internal ma...
# 3  RT @PandaJay: Really, #UNHRC ?\nNo court inter...
# 4  #CAA_NRC_NPR \nIndia's image gets severe beati...
# 5  RT @AskAnshul: Anti CAA rally in Goa's Benauli...
# 6  RT @iDarshanBJP: बांग्लादेशी, रोहिंग्या और पाक...
# 7  RT @ndtvindia: BJP नेता ने CAA का विरोध करने व...
# 8  RT @ABPNews: #UN मानवाधिकार प्रमुख ने #CAA को ...
# 9  RT @OpIndia_com: On Tuesday, the MEA spokesper...

# %%
sid = SentimentIntensityAnalyzer()

listy = []
for index,row in data.iterrows():
    ss = sid.polarity_scores(row['Tweets'])
    listy.append(ss)
se = pd.Series(listy)
data['Polarity'] = se.values

# %%
data
# Out:
#                                                Tweets  \
# 0   @aishvaryaV @TalwaiSarita @sandipanthedeb @Suh...
# 1   RT @pbhushan1: Do read this fine intervention ...
# 2   RT @ishkarnBHANDARI: Congress took internal ma...
# 3   RT @PandaJay: Really, #UNHRC ?\nNo court inter...
# 4   #CAA_NRC_NPR \nIndia's image gets severe beati...
# ..                                                ...
# 95  RT @erkekleriinsesi: Araştırma yapmışlar, Türk...
# 96  RT @OpIndia_com: On Tuesday, the MEA spokesper...
# 97  RT @SarojMi86385397: CAA का विरोध सच्चा हिन्दू...
# 98  RT @OpIndia_com: On Tuesday, the MEA spokesper...
# 99  RT @anilkumar1925: #Exposed Anti-CAA विरोधियों...
#
#                                              Polarity
# 0   {'neg': 0.161, 'neu': 0.839, 'pos': 0.0, 'comp...
# 1   {'neg': 0.087, 'neu': 0.83, 'pos': 0.083, 'com...
# 2   {'neg': 0.12, 'neu': 0.639, 'pos': 0.241, 'com...
# 3   {'neg': 0.127, 'neu': 0.873, 'pos': 0.0, 'comp...
# 4   {'neg': 0.483, 'neu': 0.517, 'pos': 0.0, 'comp...
# ..                                                ...
# 95  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 96  {'neg': 0.091, 'neu': 0.909, 'pos': 0.0, 'comp...
# 97  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 98  {'neg': 0.091, 'neu': 0.909, 'pos': 0.0, 'comp...
# 99  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
#
# [100 rows x 2 columns]
